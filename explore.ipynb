# %%
import pandas as pd
import os

# Define the path to the general folder
general_folder_path = '/Users/proxim/PROXIM/PROJECTS/olympics2024-analysis/data/CSV_files/general'

# List of CSV files in the general folder
general_files = [
    'athletes.csv', 'coaches.csv', 'events.csv', 'medallists.csv', 'medals_total.csv', 'medals.csv',
    'nocs.csv', 'schedules_preliminary.csv', 'schedules.csv', 'teams.csv', 'technical_officials.csv',
    'torch_route.csv', 'venues.csv'
]

# Load and display the structure of each CSV file in the general folder
for file in general_files:
    file_path = os.path.join(general_folder_path, file)
    df = pd.read_csv(file_path)
    print(f"File: {file}")
    print("Columns:", df.columns.tolist())
    print("First 5 rows:")
    print(df.head())
    print("\n")
# Out:
# File: athletes.csv
# Columns: ['code', 'current', 'name', 'name_short', 'name_tv', 'gender', 'function', 'country_code', 'country', 'country_long', 'nationality', 'nationality_long', 'nationality_code', 'height', 'weight', 'disciplines', 'events', 'birth_date', 'birth_place', 'birth_country', 'residence_place', 'residence_country', 'nickname', 'hobbies', 'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero', 'influence', 'philosophy', 'sporting_relatives', 'ritual', 'other_sports']
# First 5 rows:
#       code  current               name     name_short            name_tv  \
# 0  1532872     True   ALEKSANYAN Artur   ALEKSANYAN A   Artur ALEKSANYAN
# 1  1532873     True     AMOYAN Malkhas       AMOYAN M     Malkhas AMOYAN
# 2  1532874     True    GALSTYAN Slavik     GALSTYAN S    Slavik GALSTYAN
# 3  1532944     True  HARUTYUNYAN Arsen  HARUTYUNYAN A  Arsen HARUTYUNYAN
# 4  1532945     True    TEVANYAN Vazgen     TEVANYAN V    Vazgen TEVANYAN
#
# ...

# %%
# Out:
# File: 3x3 Basketball.csv
# Columns: ['date', 'stage_code', 'event_code', 'event_name', 'event_stage', 'stage', 'gender', 'discipline_name', 'discipline_code', 'venue', 'participant_code', 'participant_name', 'participant_type', 'participant_country_code', 'participant_country', 'result', 'result_type', 'result_WLT', 'start_order']
# First 5 rows:
#                         date                          stage_code event_code  \
# 0  2024-07-30T18:59:05+02:00  BK3MTEAM3-------------GPA-000100--  BK3MTEAM3
# 1  2024-07-30T18:59:05+02:00  BK3MTEAM3-------------GPA-000100--  BK3MTEAM3
# 2  2024-07-30T19:26:55+02:00  BK3MTEAM3-------------GPA-000200--  BK3MTEAM3
# 3  2024-07-30T19:26:55+02:00  BK3MTEAM3-------------GPA-000200--  BK3MTEAM3
# 4  2024-07-30T22:30:21+02:00  BK3MTEAM3-------------GPA-000300--  BK3MTEAM3
#
#   event_name       event_stage       stage gender discipline_name  \
# 0        Men  Men's Pool Round  Pool Round      M  3x3 Basketball
# ...

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11165 entries, 0 to 11164
# Data columns (total 48 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code                  11165 non-null  object
#  1   current               11165 non-null  bool
#  2   name_athlete          11165 non-null  object
#  3   name_short            11162 non-null  object
#  4   name_tv               11162 non-null  object
#  5   gender_athlete        11165 non-null  object
#  6   function              11165 non-null  object
#  7   country_code_athlete  11165 non-null  object
#  8   country_athlete       11165 non-null  object
#  9   country_long_athlete  11165 non-null  object
#  10  nationality           11162 non-null  object
#  11  nationality_long      11162 non-null  object
#  12  nationality_code      11162 non-null  object
#  13  height                11162 non-null  float64
#  14  weight                11160 non-null  float64
# ...
